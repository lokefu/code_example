# %%
import os
from glob import glob
import re
import shutil

data_path = 'src/human' 
image_paths = sorted(glob(f"{data_path}/*.mp4"), key=lambda x: int(re.search(r'(\d+).mp4', os.path.basename(x)).group(1)))

##visualize
output_folder = 'output_human'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
else:
    shutil.rmtree(output_folder)
    os.makedirs(output_folder)

for i in image_paths:
    gif_name = i[10:-4] #[7:-4]
    gif_path = f'{output_folder}/{gif_name}.GIF'
    # !python3 frame_diff.py --output_gif {gif_path} --thresh 1000 --video_path {i}
# Out:
# the box thresh:  1000
# data.csv has been deleted.
# the output file:  data.csv
# start to visualize the box on the images
# output_human/uid_vid_00000.GIF does not exist.
# start to create GIF
# the box thresh:  1000
# data.csv has been deleted.
# the output file:  data.csv
# start to visualize the box on the images
# output_human/uid_vid_00001.GIF does not exist.
# start to create GIF
# the box thresh:  1000
# data.csv has been deleted.
# the output file:  data.csv
# start to visualize the box on the images
# output_human/uid_vid_00004.GIF does not exist.
# start to create GIF
# the box thresh:  1000
# data.csv has been deleted.
# the output file:  data.csv
# start to visualize the box on the images
# output_human/uid_vid_00006.GIF does not exist.
# start to create GIF
# the box thresh:  1000
# data.csv has been deleted.
# the output file:  data.csv
# start to visualize the box on the images
# output_human/uid_vid_00018.GIF does not exist.
# start to create GIF
# ...
