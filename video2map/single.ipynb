# %% [markdown]
# # indoor

# %%
from map_single import *
coord_src = [[450, 580], [930, 815], [890, 400], [1340, 520]]
coord_map = [[290, 270], [290, 500], [590, 270], [590, 500]]

map_path = 'input/map/map_indoor.png'
video = 'input/video/uid_vid_00103.mp4'
json_file_path = 'input/track/uid_vid_00103.mp4.json'

fps = 30
dpi = None
output_format = 'mp4' #or gif or mp4
output_filename = 'output/tracking_indoor'
map_folder = 'temp_in'
box_folder = 'temp_in_box'

main(coord_src, coord_map, map_path, video, json_file_path, output_format, output_filename, fps, map_folder, box_folder, dpi)
#convert_images_to_video('merge', 'output/tracking_outdoor.mp4', fps)
#create_gif_from_images('output/tracking_outdoor.GIF', 'merge', '.jpg')
# Out:
# compute homography matrix
# convert video to images
# read and sort json file
# draw
# map
# box
# merge
# convert images to video

# %% [markdown]
# # outdoor

# %%
#test outdoor 00000
from map_single import *

coord_src = [[750, 750], [870, 780], [1435, 375], [1550, 400]]
coord_map = [[280, 600], [280, 710], [1520, 600], [1520, 710]]

map_path = 'input/map/map_outdoor.png'
video = 'input/video/uid_vid_00000.mp4'
json_file_path = 'input/track/uid_vid_00000.mp4.json'

fps = 30
dpi = None
output_format = 'mp4' #or gif or mp4
output_filename = 'output/tracking_outdoor'
map_folder = 'temp_out'
box_folder = 'temp_out_box'

main(coord_src, coord_map, map_path, video, json_file_path, output_format, output_filename, fps, map_folder, box_folder, dpi)
#convert_images_to_video('merge', 'output/tracking_outdoor.mp4', fps)
#create_gif_from_images('output/tracking_outdoor.GIF', 'merge', '.jpg')
# Out:
# compute homography matrix
# convert video to images
# read and sort json file
# draw
# map
# box
# merge
# convert images to video
